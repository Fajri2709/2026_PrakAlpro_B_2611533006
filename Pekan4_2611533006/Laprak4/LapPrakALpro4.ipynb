# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA DAN PEMOGRAMAN**
#
# **“STRUKTUR PERCABANGAN PADA PYTHON”**
#
# **Disusun Oleh :**
#
# **Fajri Ramadhan**
#
# **2611533006**
#
# **Dosen Pengampu:**
#
# **Dr. Ir WAHYUDI, ST., MT.**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="images/logo_unand.png.jpeg" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur kehadirat Tuhan Yang Maha Esa karena atas rahmat dan karunia-Nya, laporan praktikum yang berjudul “Struktur Percabangan pada Python” ini dapat diselesaikan dengan baik.
#
# Laporan ini disusun sebagai salah satu bentuk dokumentasi dan pertanggungjawaban dalam pelaksanaan praktikum pemrograman. Melalui praktikum ini, diharapkan dapat memahami konsep dasar struktur percabangan pada bahasa pemrograman Python serta penerapannya dalam membuat program yang dapat mengambil keputusan berdasarkan kondisi tertentu.
#
# Dalam pemrograman, struktur percabangan merupakan salah satu konsep dasar yang sangat penting karena memungkinkan sebuah program menjalankan perintah yang berbeda sesuai dengan kondisi yang diberikan. Python menyediakan beberapa bentuk struktur percabangan, seperti if, if-else, dan if-elif-else, yang dapat digunakan sesuai dengan kebutuhan program.
#
# Penulis menyadari bahwa laporan ini masih memiliki kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan untuk menyempurnakan laporan ini. Semoga laporan ini dapat memberikan manfaat dan menambah pengetahuan bagi pembaca mengenai struktur percabangan pada Python.
#
# Padang, 2026
#
# Fajri Ramadhan

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Perkembangan teknologi informasi menyebabkan pemrograman menjadi salah satu kemampuan yang penting untuk dipelajari. Pemrograman digunakan untuk membuat berbagai macam aplikasi dan sistem yang dapat membantu manusia dalam menyelesaikan pekerjaan secara lebih efektif dan efisien. Salah satu bahasa pemrograman yang banyak digunakan untuk mempelajari dasar-dasar pemrograman adalah Python.
#
# Dalam membuat sebuah program, diperlukan suatu mekanisme agar program dapat menentukan tindakan yang harus dilakukan berdasarkan kondisi tertentu. Mekanisme tersebut disebut dengan struktur percabangan. Struktur percabangan memungkinkan program memilih dan menjalankan perintah tertentu apabila suatu kondisi terpenuhi.
#
# Python menyediakan struktur percabangan yang sederhana dan mudah dipahami. Beberapa bentuk percabangan yang umum digunakan adalah if, if-else, serta if-elif-else. Dengan struktur tersebut, program dapat menghasilkan keluaran yang berbeda berdasarkan nilai atau kondisi yang diberikan oleh pengguna.
#
# Pemahaman mengenai struktur percabangan sangat penting karena konsep ini merupakan dasar dalam pembuatan program yang lebih kompleks. Oleh karena itu, praktikum mengenai struktur percabangan pada Python dilakukan agar dapat memahami cara kerja, penulisan sintaks, serta penerapannya dalam sebuah program.
#
# ## 1.2 Tujuan
# 1. Mengetahui pengertian dan fungsi struktur percabangan pada Python.
# 2. Memahami penggunaan perintah if, if-else, dan if-elif-else.
# 3. Mengetahui cara membuat kondisi dalam program Python.
# 4. Mampu menerapkan struktur percabangan dalam pembuatan program sederhana.
# 5. Melatih kemampuan berpikir logis dan sistematis dalam menyelesaikan permasalahan menggunakan program.
# ## 1.3 Manfaat
# 1. Menambah pemahaman mengenai konsep dasar pemrograman Python.
# 2. Mengetahui cara membuat program yang dapat mengambil keputusan berdasarkan kondisi.
# 3. Meningkatkan kemampuan dalam menggunakan operator perbandingan dan operator logika.
# 4. Melatih kemampuan menganalisis suatu permasalahan sebelum membuat program.
# 5. Menjadi dasar untuk mempelajari struktur program Python yang lebih kompleks.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# ### 2.1.1 Pengertian Struktur Percabangan
# Struktur percabangan adalah struktur dalam pemrograman yang digunakan untuk menentukan perintah yang akan dijalankan berdasarkan kondisi tertentu. Dengan adanya percabangan, program tidak hanya menjalankan instruksi secara berurutan, tetapi dapat memilih tindakan sesuai dengan hasil pemeriksaan suatu kondisi.
#
# Sebagai contoh, sebuah program dapat menentukan apakah seorang siswa lulus atau tidak lulus berdasarkan nilai yang diperoleh. Jika nilai memenuhi batas yang ditentukan, program akan menampilkan keterangan lulus. Sebaliknya, jika nilai tidak memenuhi batas tersebut, program akan menampilkan keterangan tidak lulus.
#
# ### 2.1.2 Percabangan if
# Percabangan if digunakan ketika program hanya perlu menjalankan suatu perintah apabila kondisi tertentu bernilai benar (True).
#
# Bentuk umum:
#
# if kondisi:
#
#     perintah
#
# Contoh:
#
# nilai = 80
#
# if nilai >= 75:
#
#     print("Lulus")
#
# Pada contoh tersebut, program akan menampilkan “Lulus” apabila nilai lebih besar atau sama dengan 75. Jika kondisi bernilai salah, perintah di dalam if tidak akan dijalankan.
#
# ### 2.1.3 Percabangan if-else
# Percabangan if-else digunakan ketika terdapat dua kemungkinan tindakan. Jika kondisi bernilai benar, program menjalankan bagian if. Jika kondisi bernilai salah, program menjalankan bagian else.
#
# Bentuk umum:
#
# if kondisi:
#
#     perintah_jika_benar
#
# else:
#
#     perintah_jika_salah
#
# Contoh:
#
# nilai = 60
#
# if nilai >= 75:
#
#     print("Lulus")
#
# else:
#
#     print("Tidak Lulus")
#
# Pada program tersebut, karena nilai adalah 60, kondisi nilai >= 75 bernilai salah sehingga program menampilkan “Tidak Lulus”.
#
# ### 2.1.4 Percabangan if-elif-else
# Percabangan if-elif-else digunakan apabila terdapat lebih dari dua kondisi yang harus diperiksa. Python akan memeriksa kondisi dari atas ke bawah. Perintah pada kondisi pertama yang bernilai benar akan dijalankan.
#
# Bentuk umum:
#
# if kondisi1:
#
#     perintah1
#
# elif kondisi2:
#
#     perintah2
#
# else:
#
#     perintah3
#
# Contoh:
#
# nilai = 85
#
# if nilai >= 90:
#
#     print("Sangat Baik")
#
# elif nilai >= 75:
#
#     print("Baik")
#
# else:
#
#     print("Perlu Belajar Lagi")
#
# Karena nilai adalah 85, kondisi pertama tidak terpenuhi, sedangkan kondisi kedua terpenuhi. Oleh karena itu, program menampilkan “Baik”.
#
# ### 2.1.5 Operator Perbandingan
# Operator perbandingan digunakan untuk membandingkan dua nilai dan menghasilkan nilai Boolean, yaitu True atau False.
#
# Beberapa operator perbandingan dalam Python adalah:
#
# Operator	Keterangan	Contoh
#
# `==	Sama dengan	a == b`
#
# `!=	Tidak sama dengan	a != b`
#
# `>	Lebih besar dari	a > b`
#
# `<	Lebih kecil dari	a < b`
#
# `>=	Lebih besar atau sama dengan	a >= b`
#
# `<=	Lebih kecil atau sama dengan	a <= b`
#
# Operator tersebut sering digunakan sebagai kondisi dalam struktur percabangan.
#
# ### 2.1.6 Operator Logika
# Operator logika digunakan untuk menggabungkan atau memanipulasi beberapa kondisi. Dalam Python terdapat beberapa operator logika, yaitu:
#
# and digunakan apabila semua kondisi harus bernilai benar.
#
# or digunakan apabila salah satu kondisi bernilai benar.
#
# not digunakan untuk membalik nilai suatu kondisi.
#
# Contoh:
#
# umur = 20
#
# memiliki_kartu = True
#
# if umur >= 17 and memiliki_kartu:
#
#     print("Syarat terpenuhi")
#
# Pada contoh tersebut, kedua kondisi harus bernilai benar agar perintah di dalam if dijalankan.
#
# ### 2.1.7 Indentasi pada Python
# Indentasi merupakan bagian penting dalam penulisan program Python. Indentasi digunakan untuk menunjukkan blok kode yang termasuk dalam suatu struktur, seperti if, else, atau elif.
#
# Contoh yang benar:
#
# nilai = 80
#
# if nilai >= 75:
#     print("Lulus")
#
# Perintah print() diberi indentasi sehingga menjadi bagian dari blok if. Kesalahan indentasi dapat menyebabkan program menghasilkan kesalahan atau tidak berjalan sesuai dengan yang diharapkan.
#
# 2.1.8 Contoh Penerapan Struktur Percabangan
# Berikut contoh program sederhana untuk menentukan kategori nilai:
#
# nilai = int(input("Masukkan nilai: "))
#
# if nilai >= 90:
#
#       print("Predikat A")
#
# elif nilai >= 80:
#
#     print("Predikat B")
#
# elif nilai >= 70:
#
#     print("Predikat C")
#
# elif nilai >= 60:
#
#     print("Predikat D")
#
# else:
#
#     print("Predikat E")
#
# Program tersebut meminta pengguna memasukkan nilai. Selanjutnya, program membandingkan nilai tersebut dengan beberapa kondisi secara berurutan dan menampilkan predikat yang sesuai.
#
# Dari contoh tersebut dapat diketahui bahwa struktur percabangan membuat program mampu mengambil keputusan secara otomatis berdasarkan data yang diberikan oleh pengguna.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "if1_2611533006"

# %%
# Buat file dengan nama if1_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh; ipk_1234
# Program ini menggunakan fungsi input()

ipk_3006 = float(input("Input IPK Anda = "))

if ipk_3006 > 2.75:
    print("Anda lulus Sangat Memuaskan dengan IPK " + str(ipk_3006))

print("Program Selesai")
# Out:
# Anda lulus Sangat Memuaskan dengan IPK 4.0
# Program Selesai

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 berfungsi untuk meminta pengguna memasukkan nilai IPK. Fungsi `float()` digunakan untuk mengubah input menjadi tipe data desimal dan hasilnya disimpan dalam variabel `ipk_3006`.
#
# 2. Baris 3 berfungsi untuk melakukan percabangan menggunakan `if`. Kondisi `ipk_3006 >= 2.75` digunakan untuk memeriksa apakah nilai IPK pengguna lebih besar atau sama dengan 2,75.
#
# 3. Baris 4 berfungsi untuk menampilkan pesan bahwa pengguna lulus sangat memuaskan apabila kondisi pada `if` terpenuhi. Fungsi `str()` digunakan untuk mengubah nilai IPK menjadi teks agar dapat digabungkan dengan string menggunakan operator `+`.
#
# 4. Baris 6 berfungsi untuk menampilkan pesan bahwa program telah selesai dijalankan. Baris ini tetap dijalankan meskipun kondisi pada `if` tidak terpenuhi karena tidak berada di dalam blok `if`.

# %% [markdown]
# ### 2.2.2 Program "if2_2611533006

# %%
# Buat file dengan nama if2_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh; ipk_1234
# Program ini menggunakan fungsi input()

ipk_3006 = float(input("Input IPK Anda = "))

if ipk_3006 > 2.75:
    print("Anda lulus Sangat Memuaskan dengan IPK " + str(ipk_3006))
else:
    print("Anda Tidak Lulus")
print("Program Selesai")
# Out:
# Anda lulus Sangat Memuaskan dengan IPK 4.0
# Program Selesai

# %% [markdown]
# **Penjelasan :**
# 1. **Baris 1** berfungsi untuk meminta pengguna memasukkan nilai IPK. Fungsi `float()` digunakan untuk mengubah input menjadi tipe data desimal dan disimpan ke dalam variabel `ipk_3006`.
#
# 2. **Baris 3** berfungsi untuk melakukan percabangan menggunakan `if` dengan kondisi `ipk_3006 > 2.75`, yaitu memeriksa apakah nilai IPK lebih besar dari 2,75.
#
# 3. **Baris 4** berfungsi untuk menampilkan pesan bahwa pengguna lulus sangat memuaskan beserta nilai IPK apabila kondisi pada `if` terpenuhi. Fungsi `str()` digunakan untuk mengubah nilai IPK menjadi teks agar dapat digabungkan dengan teks menggunakan operator `+`.
#
# 4. **Baris 5** merupakan bagian `else` yang berfungsi untuk menjalankan perintah ketika kondisi `if` tidak terpenuhi.
#
# 5. **Baris 6** berfungsi untuk menampilkan pesan **"Anda Tidak Lulus"** apabila nilai IPK tidak lebih dari 2,75.
#
# 6. **Baris 7** berfungsi untuk menampilkan pesan **"Program selesai"** setelah seluruh proses percabangan selesai dijalankan.

# %% [markdown]
# ### 2.2.3 Program "multi_if1_2611533006"

# %%
# Buat file dengan nama multi_if1_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh; ipk_1234
# Program ini menggunakan fungsi input()

umur_3006 = int(input("Input umur anda: "))
sim_3006 = input("Apakah Anda Sudah Punya Sim C (y/t): ")[0]

if umur_3006 >= 17 and sim_3006 == 'y':
    print("Anda Sudah dewasa dan boleh bawa motor")

if umur_3006 >= 17 and sim_3006 != 'y':
    print("Anda Sudah dewasa tetapi tidak boleh bawa motor")

if umur_3006 < 17 and sim_3006 == 'y':
    print("Anda Belum Cukup Umur punya SIM")

if umur_3006 < 17 and sim_3006 != 'y':
    print("Anda Belum Cukup Umur bawa motor")
# Out:
# Anda Sudah dewasa tetapi tidak boleh bawa motor

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 merupakan komentar yang menjelaskan bahwa program menggunakan fungsi `input()` untuk menerima data dari pengguna.
#
# 2. Baris 3 berfungsi untuk meminta pengguna memasukkan umur. Fungsi `int()` digunakan untuk mengubah input menjadi bilangan bulat dan menyimpannya ke dalam variabel `umur_3006`.
#
# 3. Baris 4 berfungsi untuk meminta informasi apakah pengguna memiliki SIM C. `[0]` digunakan untuk mengambil karakter pertama dari input, kemudian hasilnya disimpan dalam variabel `sim_3006`.
#
# 4. Baris 6 berfungsi untuk memeriksa apakah pengguna sudah berusia minimal 17 tahun dan memiliki SIM C. Operator `and` digunakan agar kedua kondisi harus terpenuhi. Jika benar, program menampilkan bahwa pengguna boleh membawa motor.
#
# 5. Baris 9 berfungsi untuk memeriksa apakah pengguna sudah berusia minimal 17 tahun tetapi tidak memiliki SIM C. Operator `!=` digunakan untuk menyatakan bahwa SIM bukan `y`. Jika kondisi terpenuhi, program menampilkan bahwa pengguna tidak boleh membawa motor.
#
# 6. Baris 12 berfungsi untuk memeriksa apakah pengguna belum berusia 17 tahun dan tidak memiliki SIM C. Jika kedua kondisi terpenuhi, program menampilkan bahwa pengguna belum cukup umur untuk membawa motor.
#
# 7. Baris 15 berfungsi untuk memeriksa apakah pengguna belum berusia 17 tahun tetapi memiliki SIM C. Jika kondisi terpenuhi, program menampilkan bahwa pengguna belum cukup umur untuk memiliki SIM.

# %% [markdown]
# ### 2.2.4 Program "if_elif_else1_2611533006"

# %%
# Buat file dengan nama if_elif_else1_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh; ipk_1234
# Program ini menggunakan fungsi input()

umur_3006 = int(input("Input umur anda: "))
sim_3006 = input("Apakah Anda Sudah Punya Sim C : ")[0]

if umur_3006 >= 17 and sim_3006 == 'y':
    print("Anda Sudah dewasa dan boleh bawa motor")
elif umur_3006 >= 17 and sim_3006 != 'y':
    print("Anda Sudah dewasa tetapi tidak boleh bawa motor")
elif umur_3006 < 17 and sim_3006 == 'y':
    print("Anda Belum Cukup Umur punya SIM")
else:
    print("Anda Belum Cukup Umur dan tidak boleh bawa motor")
print("Program Selesai")
# Out:
# Anda Sudah dewasa tetapi tidak boleh bawa motor
# Program Selesai

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 merupakan komentar yang menjelaskan bahwa program menggunakan fungsi `input()` untuk menerima data dari pengguna.
#
# 2. Baris 3 berfungsi untuk meminta pengguna memasukkan umur. Fungsi `int()` digunakan untuk mengubah input menjadi bilangan bulat dan disimpan dalam variabel `umur_3006`.
#
# 3. Baris 4 berfungsi untuk meminta pengguna memasukkan informasi apakah sudah memiliki SIM C. `[0]` digunakan untuk mengambil karakter pertama dari input dan disimpan dalam variabel `sim_3006`.
#
# 4. Baris 6 berfungsi untuk memeriksa apakah umur pengguna minimal 17 tahun dan memiliki SIM C. Operator `and` digunakan agar kedua kondisi harus terpenuhi.
#
# 5. Baris 7 berfungsi untuk menampilkan pesan bahwa pengguna sudah dewasa dan boleh membawa motor jika kondisi pada baris sebelumnya terpenuhi.
#
# 6. Baris 8 berfungsi untuk memeriksa apakah pengguna sudah berusia minimal 17 tahun tetapi tidak memiliki SIM C. Operator `!=` digunakan untuk menunjukkan bahwa input SIM bukan `y`.
#
# 7. Baris 9 berfungsi untuk menampilkan pesan bahwa pengguna sudah dewasa tetapi tidak boleh membawa motor jika kondisi kedua terpenuhi.
#
# 8. Baris 10 berfungsi untuk memeriksa apakah pengguna berusia kurang dari 17 tahun tetapi memiliki SIM C.
#
# 9. Baris 11 berfungsi untuk menampilkan pesan bahwa pengguna belum cukup umur untuk memiliki SIM jika kondisi ketiga terpenuhi.
#
# 10. Baris 12 merupakan bagian `else` yang berfungsi untuk menangani kondisi ketika semua kondisi sebelumnya tidak terpenuhi.
#
# 11. Baris 13 berfungsi untuk menampilkan pesan bahwa pengguna belum cukup umur dan tidak boleh membawa motor.
#
# 12. Baris 15 berfungsi untuk menampilkan pesan "Program Selesai" setelah seluruh proses percabangan selesai dijalankan.

# %% [markdown]
# ### 2.2.5 Program "multi_if2_2611533006"

# %%
# Buat file dengan nama multi_if2_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh; total_belanja_1234
# Program ini menggunakan fungsi input()
# Program Menghitung Diskon Belanja

# Input dari user
total_belanja_3006 = float(input("Masukkan total belanja (Rp): "))

# Input status member (mengecek apakah user mengetik 'y' atau 'ya')
input_member_3006 = input("Apakah Anda member? (y/t): ").strip().lower()
is_member_3006 = input_member_3006 in ["y", "ya"]

# Input status kode promo (mengecek apakah user mengetik 'y' atau 'ya')
input_promo_3006 = input("Apakah kode promo valid? (y/t): ").strip().lower()
kode_promo_valid_3006 = input_promo_3006 in ["y", "ya"]

total_diskon_persen_3006 = 0

# Multi-IF terpisah: Setiap kondisi diperiksa secara independen
# Diskon bisa ditumpuk (akumulasi) jika memenuhi beberapa syarat sekaligus

if total_belanja_3006 > 1000000:
    total_diskon_persen_3006 += 10 # Diskon belanja besar

if is_member_3006:
    total_diskon_persen_3006 += 5 # Diskon member

if kode_promo_valid_3006:
    total_diskon_persen_3006 += 15 # Diskon voucher

# Menghitung nominal diskon dan total bayar
nominal_diskon_3006 = total_belanja_3006 * (total_diskon_persen_3006 / 100)
total_bayar_3006 = total_belanja_3006 - nominal_diskon_3006

# Output hasil
print("\n--- Rincian Pembayaran ---")
print(f"Total Diskon : {total_diskon_persen_3006}% (Rp {nominal_diskon_3006:,.0f})")
print(f"Total Bayar  : Rp {total_bayar_3006:,.0f}")

print(f"Total diskon yang Anda dapatkan: {total_diskon_persen_3006}%")
# Output: Total diskon yang Anda dapatkan: 30% jika belanja > 1 juta, member , dan kode promo valid
# Out:
# --- Rincian Pembayaran ---
# Total Diskon : 20% (Rp 200,000)
# Total Bayar  : Rp 800,000
# Total diskon yang Anda dapatkan: 20%

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 merupakan komentar yang menjelaskan bahwa program menggunakan fungsi `input()` untuk menerima data dari pengguna.
#
# 2. Baris 2 merupakan komentar yang menjelaskan bahwa program digunakan untuk menghitung diskon belanja.
#
# 3. Baris 5 berfungsi untuk meminta pengguna memasukkan total belanja. Fungsi `float()` digunakan agar nilai yang dimasukkan dapat berupa bilangan desimal dan disimpan dalam variabel `total_belanja_3006`.
#
# 4. Baris 8 berfungsi untuk meminta status keanggotaan pengguna. Fungsi `.strip()` digunakan untuk menghapus spasi yang tidak diperlukan, sedangkan `.lower()` digunakan untuk mengubah input menjadi huruf kecil.
#
# 5. Baris 9 berfungsi untuk menentukan apakah pengguna merupakan member. Kondisi `in ["y", "ya"]` akan menghasilkan nilai `True` jika pengguna memasukkan `y` atau `ya`, kemudian hasilnya disimpan dalam variabel `is_member_3006`.
#
# 6. Baris 12 berfungsi untuk meminta pengguna memasukkan status kode promo. Input dibersihkan menggunakan `.strip()` dan diubah menjadi huruf kecil menggunakan `.lower()`.
#
# 7. Baris 13 berfungsi untuk menentukan apakah kode promo yang dimasukkan valid. Jika pengguna memasukkan `y` atau `ya`, variabel `kode_promo_valid_3006` akan bernilai `True`.
#
# 8. Baris 15 berfungsi untuk menginisialisasi nilai total diskon sebesar `0%`. Nilai ini nantinya akan bertambah sesuai dengan kondisi yang terpenuhi.
#
# 9. Baris 20 berfungsi untuk memeriksa apakah total belanja lebih dari Rp1.000.000. Jika kondisi terpenuhi, program menambahkan diskon sebesar `10%` menggunakan operator `+=`.
#
# 10. Baris 23 berfungsi untuk memeriksa apakah pengguna merupakan member. Jika bernilai `True`, program menambahkan diskon member sebesar `5%`.
#
# 11. Baris 26 berfungsi untuk memeriksa apakah kode promo valid. Jika bernilai `True`, program menambahkan diskon voucher sebesar `15%`.
#
# 12. Baris 29 berfungsi untuk menghitung nominal diskon. Nilai total belanja dikalikan dengan persentase diskon yang telah dibagi `100` agar menjadi nilai desimal.
#
# 13. Baris 30 berfungsi untuk menghitung total pembayaran setelah dikurangi nominal diskon dari total belanja.
#
# 14. Baris 33 berfungsi untuk menampilkan judul bagian rincian pembayaran.
#
# 15. Baris 34 berfungsi untuk menampilkan total persentase diskon dan nominal diskon yang diperoleh. Format `:,.0f` digunakan agar nominal ditampilkan dengan pemisah ribuan tanpa angka desimal.
#
# 16. Baris 35 berfungsi untuk menampilkan total pembayaran setelah mendapatkan diskon.
#
# 17. Baris 37 berfungsi untuk menampilkan kembali jumlah total diskon yang diperoleh oleh pengguna.
#
# 18. Baris 38 merupakan komentar yang memberikan contoh hasil. Jika pengguna berbelanja lebih dari Rp1.000.000, merupakan member, dan memiliki kode promo yang valid, maka seluruh diskon akan terakumulasi menjadi 30%.

# %% [markdown]
# ### 2.2.6 Program "nilai_2611533006"

# %%
# Buat file dengan nama nilai_nim.py
# Buat program untuk nested if
# Nama variabel ditambah 4 digit nim terakhir contoh; ipk_1234
# Program ini menggunakan fungsi input()
# Program konversi nilai angka menjadi huruf

nilai_3006 = int(input("Inputkan nilai angka: "))

if nilai_3006 >= 81:
    print("A")
elif nilai_3006 >= 70:
    print("B")
elif nilai_3006 >= 60:
    print("C")
elif nilai_3006 >= 50:
    print("D")
else:
    print("E")
# Out:
# A

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 merupakan komentar yang menjelaskan bahwa program digunakan untuk mengubah nilai angka menjadi nilai huruf.
#
# 2. Baris 3 berfungsi untuk meminta pengguna memasukkan nilai angka. Fungsi `int()` digunakan untuk mengubah input menjadi bilangan bulat dan menyimpannya dalam variabel `nilai_3006`.
#
# 3. Baris 5 berfungsi untuk memeriksa apakah nilai yang dimasukkan lebih besar atau sama dengan 81. Jika kondisi terpenuhi, program akan menjalankan perintah pada baris berikutnya.
#
# 4. Baris 6 berfungsi untuk menampilkan nilai huruf "A" jika nilai angka lebih besar atau sama dengan 81.
#
# 5. Baris 7 berfungsi untuk memeriksa kondisi berikutnya menggunakan `elif`, yaitu apakah nilai lebih besar atau sama dengan 70. Kondisi ini diperiksa jika kondisi sebelumnya tidak terpenuhi.
#
# 6. Baris 8 berfungsi untuk menampilkan nilai huruf "B" jika nilai angka berada pada rentang 70 sampai 80.
#
# 7. Baris 9 berfungsi untuk memeriksa apakah nilai lebih besar atau sama dengan 60 jika kondisi sebelumnya tidak terpenuhi.
#
# 8. Baris 10 berfungsi untuk menampilkan nilai huruf "C" jika nilai angka berada pada rentang 60 sampai 69.
#
# 9. Baris 11 berfungsi untuk memeriksa apakah nilai lebih besar atau sama dengan 50 jika seluruh kondisi sebelumnya tidak terpenuhi.
#
# 10. Baris 12 berfungsi untuk menampilkan nilai huruf "D" jika nilai angka berada pada rentang 50 sampai 59.
#
# 11. Baris 13 merupakan bagian `else` yang digunakan untuk menangani nilai yang tidak memenuhi seluruh kondisi sebelumnya.
#
# 12. Baris 14 berfungsi untuk menampilkan nilai huruf "E" jika nilai angka kurang dari 50.

# %% [markdown]
# ### 2.2.7 Program "match_case1_2611533006"

# %%
# Buat file dengan nama match_case1_nim.py
# Buat program untuk match case
# Nama variabel ditambah 4 digit nim terakhir contoh; ipk_1234
# Program ini menggunakan fungsi input()
# Program konversi angka menjadi nama bulan

bulan_3006 = int(input("Masukkan angka bulan (1-12): "))

match bulan_3006:
    case 1:
        print("Januari")
    case 2:
        print("Februari")
    case 3:
        print("Maret")
    case 4:
        print("April")
    case 5:
        print("Mei")
    case 6:
        print("Juni")
    case 7:
        print("Juli")
    case 8:
        print("Agustus")
    case 9:
        print("September")
    case 10:
        print("Oktober")
    case 11:
        print("November")
    case 12:
        print("Desember")
    case _:
        print("Angka tidak valid")
# Out:
# April

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 merupakan komentar yang menjelaskan bahwa program digunakan untuk mengubah angka menjadi nama bulan.
#
# 2. Baris 3 berfungsi untuk meminta pengguna memasukkan angka bulan dari 1 sampai 12. Fungsi `int()` digunakan untuk mengubah input menjadi bilangan bulat dan menyimpannya dalam variabel `bulan_3006`.
#
# 3. Baris 5 berfungsi untuk memulai struktur percabangan `match-case`. Nilai pada variabel `bulan_3006` akan dibandingkan dengan setiap `case` yang tersedia.
#
# 4. Baris 6–7 berfungsi untuk memeriksa apakah angka yang dimasukkan adalah 1. Jika sesuai, program menampilkan nama bulan "Januari".
#
# 5. Baris 8–9 berfungsi untuk memeriksa angka 2 dan menampilkan nama bulan "Februari" jika sesuai.
#
# 6. Baris 10–11 berfungsi untuk memeriksa angka 3 dan menampilkan nama bulan "Maret" jika sesuai.
#
# 7. Baris 12–13 berfungsi untuk memeriksa angka 4 dan menampilkan nama bulan "April" jika sesuai.
#
# 8. Baris 14–15 berfungsi untuk memeriksa angka 5 dan menampilkan nama bulan "Mei" jika sesuai.
#
# 9. Baris 16–17 berfungsi untuk memeriksa angka 6 dan menampilkan nama bulan "Juni" jika sesuai.
#
# 10. Baris 18–19 berfungsi untuk memeriksa angka 7 dan menampilkan nama bulan "Juli" jika sesuai.
#
# 11. Baris 20–21 berfungsi untuk memeriksa angka 8 dan menampilkan nama bulan "Agustus" jika sesuai.
#
# 12. Baris 22–23 berfungsi untuk memeriksa angka 9 dan menampilkan nama bulan "September" jika sesuai.
#
# 13. Baris 24–25 berfungsi untuk memeriksa angka 10 dan menampilkan nama bulan "Oktober" jika sesuai.
#
# 14. Baris 26–27 berfungsi untuk memeriksa angka 11 dan menampilkan nama bulan "November" jika sesuai.
#
# 15. Baris 28–29 berfungsi untuk memeriksa angka 12 dan menampilkan nama bulan "Desember" jika sesuai.
#
# 16. Baris 30–31 merupakan `case _` yang berfungsi sebagai kondisi default. Jika angka yang dimasukkan tidak sesuai dengan angka 1 sampai 12, program akan menampilkan pesan "Angka tidak valid".

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
# Sebuah wahana rekreasi petualangan membutuhkan sistem loket berbasis konsol untuk menentukan jenis wahana, memverifikasi kelaikan pengunjung dengan kondisi majemuk (logical operators), menghitung diskon akumulatif menggunakan multi-if terpisah, serta mencetak audit status operasional.

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "Tugas4_2611533006"

# %%
print("=== SISTEM LOKET ALPRO ADVENTURE PARK ===")

# 1. Input Data Pengunjung & String Handling
nama_3006 = input("Masukkan Nama Pengunjung        : ")
umur_3006 = int(input("Input umur anda                 : "))

sim_input_3006 = input("Apakah Anda Sudah Punya SIM C (y/t): ").strip().lower()
sim_3006 = sim_input_3006[0] if sim_input_3006 else 't'

# 2. Pemilihan Wahana Menggunakan match-case
print("\nPilihan Paket Wahana (1-5):")
print("  1. Safari Rimba         (Rp 50,000)")
print("  2. Arung Jeram          (Rp 75,000)")
print("  3. Motor ATV Ekstrim    (Rp 120,000)")
print("  4. Roller Coaster Kilat (Rp 100,000)")
print("  5. All-Access VIP       (Rp 220,000)")

pilihan_3006 = int(input("Masukkan nomor paket (1-5)      : "))

# Variabel awal paket wahana
nama_paket_3006 = ""
harga_satuan_3006 = 0

match pilihan_3006:
    case 1:
        nama_paket_3006 = "Wahana Safari Rimba"
        harga_satuan_3006 = 50000
    case 2:
        nama_paket_3006 = "Wahana Arung Jeram"
        harga_satuan_3006 = 75000
    case 3:
        nama_paket_3006 = "Wahana Motor ATV Ekstrim"
        harga_satuan_3006 = 120000
    case 4:
        nama_paket_3006 = "Wahana Roller Coaster Kilat"
        harga_satuan_3006 = 100000
    case 5:
        nama_paket_3006 = "Wahana All-Access VIP"
        harga_satuan_3006 = 220000
    case _:
        print("\nPaket wahana tidak valid!")
        exit()

jumlah_tiket_3006 = int(input("Masukkan jumlah tiket           : "))

# Penerapan IF tunggal untuk validasi kuota/jumlah tiket
if jumlah_tiket_3006 <= 0:
    print("Peringatan: Jumlah tiket tidak valid! Transaksi dibatalkan.")
    exit()

is_member_3006 = input("Apakah Anda member? (y/t)       : ").strip().lower()
kode_promo_valid_3006 = input("Apakah kode promo valid? (y/t)  : ").strip().lower()

# 3. Validasi Izin Kendali Wahana Menggunakan if-elif-else dan Operator Logika
print("\n--- KELAYAKAN PENGENDARA WAHANA ---")
if pilihan_3006 == 3:
    if umur_3006 >= 17 and sim_3006 == 'y':
        print("Status Akses: Anda sudah dewasa dan boleh mengendarai ATV sendiri.")
    elif umur_3006 >= 17 and sim_3006 != 'y':
        print("Status Akses: Anda sudah dewasa tetapi tidak boleh bawa motor ATV (wajib didampingi instruktur).")
    elif umur_3006 < 17 and sim_3006 == 'y':
        print("Status Akses: Identitas tidak valid: Belum cukup umur memiliki SIM.")
    else:
        print("Status Akses: Anda belum cukup umur dan tidak boleh bawa motor ATV.")
else:
    if umur_3006 >= 10:
        print(f"Status Akses: Pengunjung memenuhi syarat usia untuk {nama_paket_3006}.")
    else:
        print(f"Status Akses: Pengunjung di bawah umur minimum (10 tahun) untuk {nama_paket_3006}.")

# 4. Akumulasi Diskon Bertingkat Menggunakan Multi-IF Terpisah
subtotal_3006 = harga_satuan_3006 * jumlah_tiket_3006
total_diskon_persen_3006 = 0

if subtotal_3006 >= 200000:
    total_diskon_persen_3006 += 10  # Diskon Belanja Besar

if is_member_3006 in ['y', 'ya']:
    total_diskon_persen_3006 += 5   # Diskon Member

if kode_promo_valid_3006 in ['y', 'ya']:
    total_diskon_persen_3006 += 15  # Diskon Voucher Promo

if jumlah_tiket_3006 >= 5:
    total_diskon_persen_3006 += 5   # Diskon Tambahan Rombongan

# 5. Evaluasi Kelulusan Audit & Rincian Pembayaran
nominal_diskon_3006 = subtotal_3006 * (total_diskon_persen_3006 / 100)
total_bayar_3006 = subtotal_3006 - nominal_diskon_3006

print("\n--- Rincian Pembayaran ---")
print(f"Subtotal Belanja : Rp {subtotal_3006:,.0f}".replace(",", "."))
print(f"Total Diskon     : {total_diskon_persen_3006}% (Rp {nominal_diskon_3006:,.0f})".replace(",", "."))
print(f"Total Bayar      : Rp {total_bayar_3006:,.0f}".replace(",", "."))

print("Catatan Layanan  : ", end="")
if total_bayar_3006 > 300000:
    print("Selamat! Anda berhak mendapatkan Souvenir Gratis.")
else:
    print("Terima kasih telah berkunjung.")

print("Program Selesai")
# Out:
# === SISTEM LOKET ALPRO ADVENTURE PARK ===
#
# Pilihan Paket Wahana (1-5):
#   1. Safari Rimba         (Rp 50,000)
#   2. Arung Jeram          (Rp 75,000)
#   3. Motor ATV Ekstrim    (Rp 120,000)
#   4. Roller Coaster Kilat (Rp 100,000)
#   5. All-Access VIP       (Rp 220,000)
#
# --- KELAYAKAN PENGENDARA WAHANA ---
# Status Akses: Pengunjung memenuhi syarat usia untuk Wahana All-Access VIP.
#
# --- Rincian Pembayaran ---
# Subtotal Belanja : Rp 660.000
# Total Diskon     : 30% (Rp 198.000)
# Total Bayar      : Rp 462.000
# Catatan Layanan  : Selamat! Anda berhak mendapatkan Souvenir Gratis.
# Program Selesai

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1–6 (# ...): Komentar header untuk memberikan informasi identitas program dan topik praktikum.
#
# 2. Baris 8 (print(...)): Mencetak judul utama sistem pada layar konsol.
#
# 3. Baris 11 (nama_3006 = input(...)): Menerima input nama pengunjung dalam bentuk string.
#
# 4. Baris 12 (umur_3006 = int(...)): Menerima input umur dan mengonversinya dari string mejadi bilangan bulat (integer).
#
# 5. Baris 14 (sim_input_3006 = ...): Menerima input status SIM, menghapus spasi di awal/akhir dengan .strip(), dan mengubah huruf menjadi kecil dengan .lower().
#
# 6. Baris 15 (sim_3006 = ...): Mengambil karakter pertama ([0]) dari input SIM (misal pengguna mengetik ya, diambil 'y'). Jika input kosong, diberi nilai default 't'.
#
# 7. Baris 18–23: Mencetak daftar menu pilihan wahana beserta harganya.
#
# 8. Baris 25 (pilihan_3006 = ...): Meminta pengguna memilih angka 1 sampai 5.
#
# 9. Baris 27–28: Inisialisasi variabel nama paket dan harga satuan dengan nilai awal kosong/nol.
#
# 10. Baris 30 (match pilihan_3006:): Membuka struktur percabangan match-case berdasarkan nilai variabel pilihan_3006.
#
# 11. Baris 31–45 (case 1: s.d. case 5:): Mengisi nilai nama_paket_3006 dan harga_satuan_3006 sesuai dengan nomor paket yang dipilih.
#
# 12. Baris 46–48 (case _: / default): Jika nomor yang dimasukkan bukan 1–5, mencetak pesan kesalahan dan menghentikan alur program menggunakan exit().
#
# 13. Baris 50 (jumlah_tiket_3006 = ...): Menerima input jumlah tiket yang ingin dibeli.
#
# 15. Baris 52–54 (if jumlah_tiket_3006 <= 0:): Implementasi IF tunggal untuk memeriksa kelogisan jumlah tiket. Jika <= 0, eksekusi program langsung dibatalkan.
#
# 16. Baris 56–57: Menerima input status keanggotaan (member) dan ketersediaan kode promo.
#
# 17. Baris 60 (if pilihan_3006 == 3:): Mengecek apakah pengguna memilih Paket 3 (Motor ATV Ekstrim).
#
# 18. Baris 61–68 (if-elif-else): Evaluasi khusus untuk ATV menggunakan operator logika and dan !=
#
# 19. Baris 69–73 (else:): Untuk wahana selain ATV, diterapkan pengecekan batasan usia umum (minimal 10 tahun).
#
# 20. Baris 75 (subtotal_3006 = ...): Menghitung harga total sebelum diskon (harga_satuan * jumlah_tiket).
#
# 21. Baris 76 (total_diskon_persen_3006 = 0): Menginisialisasi total persentase diskon dari 0.
#
# 22. Baris 78–88 (Multi-IF Independent): Empat blok if terpisah (bukan elif), sehingga kondisi dapat dievaluasi satu per satu dan diskonnya ditambah secara akumulatif (+=):
# •Jika subtotal \ge 200.000 \rightarrow diskon +10\%.
# •Jika status member \rightarrow diskon +5\%.
# •Jika kode promo valid \rightarrow diskon +15\%.
# •Jika beli \ge 5 tiket \rightarrow diskon +5\%.
#
# 23. Baris 91 (nominal_diskon_3006 = ...): Menghitung besarnya rupiah potongan harga dari total persentase diskon.
#
# 24. Baris 92 (total_bayar_3006 = ...): Menghitung tagihan bersih yang harus dibayar (subtotal - nominal_diskon).
#
# 25. Baris 95–97 (print(f"...")): Mencetak rincian biaya menggunakan f-string format angka :,.0f dan mengganti tanda koma dengan titik (.replace(",", ".")) agar sesuai dengan format rupiah Indonesia.
#
# 26. Baris 99–102 (if-else Audit): Mengevaluasi bonus berdasarkan total_bayar_3006. Jika melebihi Rp 300.000, pelanggan berhak mendapatkan souvenir gratis.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa struktur percabangan pada Python merupakan salah satu konsep dasar pemrograman yang digunakan untuk menentukan tindakan program berdasarkan kondisi tertentu. Struktur percabangan memungkinkan program menghasilkan keluaran yang berbeda sesuai dengan nilai atau kondisi yang diberikan.
#
# Python menyediakan beberapa bentuk struktur percabangan, yaitu if, if-else, dan if-elif-else. Penggunaan struktur tersebut dapat dikombinasikan dengan operator perbandingan dan operator logika untuk membuat kondisi yang lebih kompleks.
#
# Melalui praktikum ini, dapat dipahami bahwa struktur percabangan sangat berguna dalam pembuatan program karena memungkinkan program mengambil keputusan secara otomatis. Pemahaman mengenai percabangan juga menjadi dasar penting untuk mempelajari konsep pemrograman Python yang lebih lanjut.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, “The Python Tutorial: More Control Flow Tools,” Python Documentation. [Online]. Tersedia: https://docs.python.org/3/tutorial/controlflow.html [Diakses 25 September 2026].
#
# [2] Python Software Foundation, “Built-in Functions,” Python Documentation. [Online]. Tersedia: https://docs.python.org/3/library/functions.html [Diakses 25 September 2026].
#
# [3] Python Software Foundation, “Lexical Analysis: Formatted String Literals,” Python Documentation. [Online]. Tersedia: https://docs.python.org/3/reference/lexical_analysis.html [Diakses 25 September 2026].
#
# [4] Python Software Foundation, “The Python Language Reference,” Python Documentation. [Online]. Tersedia: https://docs.python.org/3/reference/ [Diakses 25 September 2026].
